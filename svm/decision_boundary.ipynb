# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.datasets import make_moons

# %%
# Generate sample data
X, y = make_classification(n_samples=100, n_features=2, n_informative=2, n_redundant=0, n_clusters_per_class=1, random_state=42)

# %%
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
def plot_decision_boundary(X, y, model, title):
    # Set the plot range
    x1_min, x1_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
    x2_min, x2_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
    
    # Create a mesh grid
    xx, yy = np.meshgrid(np.arange(x1_min, x1_max, 0.02),
                         np.arange(x2_min, x2_max, 0.02))
    
    # Make predictions on the mesh grid
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    
    # Plot the decision boundary
    plt.figure(figsize=(8, 6))
    plt.contourf(xx, yy, Z, alpha=0.4)
    plt.scatter(X[:, 0], X[:, 1], c=y,cmap='Accent_r', edgecolors='black')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.title(title)
    plt.show()

# %%
# Train a logistic regression model
lr_model = LogisticRegression(random_state=42)
lr_model.fit(X, y)

# Plot the linear decision boundary
plot_decision_boundary(X, y, lr_model, 'Linear Decision Boundary (Logistic Regression)')

# %%
x1_min, x1_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
x2_min, x2_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5

# %%
x1_min, x1_max, x2_min, x2_max
# Out:
# (np.float64(-1.3585224088380417),
#  np.float64(3.674354677420214),
#  np.float64(-2.7632311952006585),
#  np.float64(3.4712128279034298))

# %%
xx, yy = np.meshgrid(np.arange(x1_min, x1_max, 0.02),
                     np.arange(x2_min, x2_max, 0.02))

# %%
Z = lr_model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# %%
plt.figure(figsize=(10, 8))
plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='black')
# plt.xlabel('Feature 1')
# plt.ylabel('Feature 2')
# plt.title('WTF?')
plt.show()

# %%
a = np.array([2,10,11,12,4])
b = np.array([5,-2,3,12])
aa, bb = np.meshgrid(a,b)

aa,bb
# Out:
# (array([[ 2, 10, 11, 12,  4],
#         [ 2, 10, 11, 12,  4],
#         [ 2, 10, 11, 12,  4],
#         [ 2, 10, 11, 12,  4]]),
#  array([[ 5,  5,  5,  5,  5],
#         [-2, -2, -2, -2, -2],
#         [ 3,  3,  3,  3,  3],
#         [12, 12, 12, 12, 12]]))

# %%
plt.plot(xx, yy, marker='o', color='k', linestyle='none')
plt.show()

# %%
aa.ravel(), bb.ravel()
# Out:
# (array([ 2, 10, 11, 12,  4,  2, 10, 11, 12,  4,  2, 10, 11, 12,  4,  2, 10,
#         11, 12,  4]),
#  array([ 5,  5,  5,  5,  5, -2, -2, -2, -2, -2,  3,  3,  3,  3,  3, 12, 12,
#         12, 12, 12]))

# %%
np.c_[aa.ravel(), bb.ravel()]
# Out:
# array([[ 2,  5],
#        [10,  5],
#        [11,  5],
#        [12,  5],
#        [ 4,  5],
#        [ 2, -2],
#        [10, -2],
#        [11, -2],
#        [12, -2],
#        [ 4, -2],
#        [ 2,  3],
#        [10,  3],
#        [11,  3],
#        [12,  3],
#        [ 4,  3],
#        [ 2, 12],
#        [10, 12],
#        [11, 12],
#        [12, 12],
#        [ 4, 12]])

# %%
X, y = make_moons(n_samples=200, noise=0.1)

# %%
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
svm_model = SVC(kernel='rbf')
svm_model.fit(X, y)

# Plot the non-linear decision boundary
plot_decision_boundary(X, y, svm_model, 'Non-linear Decision Boundary (SVM with RBF kernel)')

# %%
a = 6.4E126

# %%
a * a * a
# Out:
# inf

# %%
class Perceptron():
   def __init__(self,w1,w2,b) :
      self.w = np.array([[w1],[w2]])
      self.b = b
      
   def predict(self, x):
      pred = []
      for item in x:
         pred.append(1 if np.dot(item,self.w) + self.b > 0 else 0)
      return np.array(pred)

# %%
# model = Perceptron()

# %%
import ipywidgets
from ipywidgets import interact

# %%
@interact(w1=(-1,1,.001), w2=(-1,1,.001),  b=(-2,2,.001))
def plot_decision_boundary( w1,w2,b):
    # Set the plot range
    x1_min, x1_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
    x2_min, x2_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
    
    # Create a mesh grid
    xx, yy = np.meshgrid(np.arange(x1_min, x1_max, 0.02),
                         np.arange(x2_min, x2_max, 0.02))
    
    # Make predictions on the mesh grid
    model = Perceptron(w1,w2,b)
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    
    # Plot the decision boundary
    plt.figure(figsize=(8, 6))
    plt.contourf(xx, yy, Z, alpha=0.4)
    plt.scatter(X[:, 0], X[:, 1], c=y,cmap='Accent_r', edgecolors='black')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
   #  plt.title(title)
    plt.show()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='w1', max=1.0, min=-1.0, step=0.001), FloatSlider(val…
